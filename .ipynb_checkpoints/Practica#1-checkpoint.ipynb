# %% [markdown]
# ## Practica#1: Data Cleaning

# %% [markdown]
# La limpieza de datos, o data cleaning, es un proceso fundamental para garantizar la calidad de los datos que se utilizan en el análisis de datos y en la toma de decisiones de una empresa

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Acer\Desktop\trabajos facu\7mo semestre\AYDR_Tareas_MineriaDeDatos\csv\steam.csv'
                 , encoding='latin-1') #FAVOR DE PONER DIRECCION ESPECIFICA DEL ARCHIVO
print(df)
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   01/11/2000        1
# 1           20       Team Fortress Classic   01/04/1999        1
# 2           30               Day of Defeat   01/05/2003        1
# 3           40          Deathmatch Classic   01/06/2001        1
# 4           50   Half-Life: Opposing Force   01/11/1999        1
# ...        ...                         ...          ...      ...
# 27070  1065230             Room of Pandora   24/04/2019        1
# 27071  1065570                   Cyber Gun   23/04/2019        1
# 27072  1065650            Super Star Blast   24/04/2019        1
# 27073  1066700  New Yankee 7: Deer Hunters   17/04/2019        1
# 27074  1069460                   Rune Lord   24/04/2019        1
#
#                 developer             publisher          platforms  \
# 0                   Valve                 Valve  windows;mac;linux
# ...

# %% [markdown]
# # Ahora veeremos un poco del proceso con codigo de python

# %%
# Eliminar filas con valores faltantes en la columna "appid"
df = df.dropna(subset=['appid'])

df
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   01/11/2000        1
# 1           20       Team Fortress Classic   01/04/1999        1
# 2           30               Day of Defeat   01/05/2003        1
# 3           40          Deathmatch Classic   01/06/2001        1
# 4           50   Half-Life: Opposing Force   01/11/1999        1
# ...        ...                         ...          ...      ...
# 27070  1065230             Room of Pandora   24/04/2019        1
# 27071  1065570                   Cyber Gun   23/04/2019        1
# 27072  1065650            Super Star Blast   24/04/2019        1
# 27073  1066700  New Yankee 7: Deer Hunters   17/04/2019        1
# 27074  1069460                   Rune Lord   24/04/2019        1
#
#                 developer             publisher          platforms  \
# 0                   Valve                 Valve  windows;mac;linux
# ...

# %%
# Eliminar duplicados
df = df.drop_duplicates()

df
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   01/11/2000        1
# 1           20       Team Fortress Classic   01/04/1999        1
# 2           30               Day of Defeat   01/05/2003        1
# 3           40          Deathmatch Classic   01/06/2001        1
# 4           50   Half-Life: Opposing Force   01/11/1999        1
# ...        ...                         ...          ...      ...
# 27070  1065230             Room of Pandora   24/04/2019        1
# 27071  1065570                   Cyber Gun   23/04/2019        1
# 27072  1065650            Super Star Blast   24/04/2019        1
# 27073  1066700  New Yankee 7: Deer Hunters   17/04/2019        1
# 27074  1069460                   Rune Lord   24/04/2019        1
#
#                 developer             publisher          platforms  \
# 0                   Valve                 Valve  windows;mac;linux
# ...

# %%
# Veemos el tipo de dato que es cada variable
print(df.dtypes)
# Out:
# appid                 int64
# name                 object
# release_date         object
# english               int64
# developer            object
# publisher            object
# platforms            object
# required_age          int64
# categories           object
# genres               object
# steamspy_tags        object
# achievements          int64
# positive_ratings      int64
# negative_ratings      int64
# average_playtime      int64
# median_playtime       int64
# owners               object
# pricexd             float64
# price               float64
# dtype: object

# %%
# Convertir la columna "edad" a tipo entero
df['required_age'] = df['required_age'].astype(int)

# Mostrar el DataFrame limpio
df
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   01/11/2000        1
# 1           20       Team Fortress Classic   01/04/1999        1
# 2           30               Day of Defeat   01/05/2003        1
# 3           40          Deathmatch Classic   01/06/2001        1
# 4           50   Half-Life: Opposing Force   01/11/1999        1
# ...        ...                         ...          ...      ...
# 27070  1065230             Room of Pandora   24/04/2019        1
# 27071  1065570                   Cyber Gun   23/04/2019        1
# 27072  1065650            Super Star Blast   24/04/2019        1
# 27073  1066700  New Yankee 7: Deer Hunters   17/04/2019        1
# 27074  1069460                   Rune Lord   24/04/2019        1
#
#                 developer             publisher          platforms  \
# 0                   Valve                 Valve  windows;mac;linux
# ...

# %%
# Eliminar columnas inecesarias
df = df.drop(columns=['required_age','steamspy_tags','achievements','pricexd' ]
             , inplace=False)
df
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   01/11/2000        1
# 1           20       Team Fortress Classic   01/04/1999        1
# 2           30               Day of Defeat   01/05/2003        1
# 3           40          Deathmatch Classic   01/06/2001        1
# 4           50   Half-Life: Opposing Force   01/11/1999        1
# ...        ...                         ...          ...      ...
# 27070  1065230             Room of Pandora   24/04/2019        1
# 27071  1065570                   Cyber Gun   23/04/2019        1
# 27072  1065650            Super Star Blast   24/04/2019        1
# 27073  1066700  New Yankee 7: Deer Hunters   17/04/2019        1
# 27074  1069460                   Rune Lord   24/04/2019        1
#
#                 developer             publisher          platforms  \
# 0                   Valve                 Valve  windows;mac;linux
# ...

# %%
# Guardar el DataFrame como un nuevo archivo CSV
df.to_csv("steam_limpio.csv", index=False)

# %%
df
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   01/11/2000        1
# 1           20       Team Fortress Classic   01/04/1999        1
# 2           30               Day of Defeat   01/05/2003        1
# 3           40          Deathmatch Classic   01/06/2001        1
# 4           50   Half-Life: Opposing Force   01/11/1999        1
# ...        ...                         ...          ...      ...
# 27070  1065230             Room of Pandora   24/04/2019        1
# 27071  1065570                   Cyber Gun   23/04/2019        1
# 27072  1065650            Super Star Blast   24/04/2019        1
# 27073  1066700  New Yankee 7: Deer Hunters   17/04/2019        1
# 27074  1069460                   Rune Lord   24/04/2019        1
#
#                 developer             publisher          platforms  \
# 0                   Valve                 Valve  windows;mac;linux
# ...
